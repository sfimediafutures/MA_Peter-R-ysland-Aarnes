# %%
import spacy
from sklearn.metrics import confusion_matrix, accuracy_score,f1_score, precision_score, recall_score, classification_report
import os
from tqdm import tqdm
import conllu
import tqdm
import torch
import json
from sklearn.metrics import confusion_matrix, classification_report
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn import functional
from functools import partial
from transformers import BertModel
from torch import nn
from transformers import BertTokenizer
import os
import pandas as pd

# %%
def transform_to_binary(set):
    binary_labels = []
    for label in set:
        if label == "O":
            binary_labels.append(0)
        else:
            binary_labels.append(1)
    return binary_labels

# %%
## Conllu stuff
def filter_tags(x):
    return x        

def convert_to_list_dict(path, file, lower=None):
    path = path.format(file)
    if lower == True:
        with open(path, encoding="UTF-8") as infile:
            lst = []
            tokens = list(conllu.parse_incr(infile))
            for sent in tokens:
                    dic = {
                    "idx": sent.metadata["sent_id"],
                    "text": sent.metadata["text"].lower(),
                    "tokens": [token["form"].lower() for token in sent],
                    "lemmas": [token["lemma"] for token in sent],
                    "pos_tags": [token["upos"] for token in sent],
                    "ner_tags": [filter_tags(token["misc"].get("name", "O")) for token in sent],
                }
                    lst.append(dic) 
            print("Converting {} to list of dictionaries\n     {} elements converted..".format(file, len(lst)))
    else:
        with open(path, encoding="UTF-8") as infile:
            lst = []
            tokens = list(conllu.parse_incr(infile))
            for sent in tokens:
                    dic = {
                    "idx": sent.metadata["sent_id"],
                    "text": sent.metadata["text"],
                    "tokens": [token["form"] for token in sent],
                    "lemmas": [token["lemma"] for token in sent],
                    "pos_tags": [token["upos"] for token in sent],
                    "ner_tags": [filter_tags(token["misc"].get("name", "O")) for token in sent],
                }
                    lst.append(dic) 
            print("Converting {} to list of dictionaries\n     {} elements converted..".format(file, len(lst)))
    return lst

# %%
path = r"C:\Users\Aarne\OneDrive - University of Bergen\Dokumenter\GitHub\MA_Peter-R-ysland-Aarnes\Results\NCRFpp\all_conllu/{0}.conllu"
file_list = ["no_bokmaal-ud-dev", "no_bokmaal-ud-test", "no_bokmaal-ud-train", "no_nynorsk-ud-dev", "no_nynorsk-ud-test", "no_nynorsk-ud-train"]
test_split_no = convert_to_list_dict(path, file_list[1], lower=True)
test_split_ny = convert_to_list_dict(path, file_list[4], lower=True)
TRUE_test_split_no = convert_to_list_dict(path, file_list[1])
TRUE_test_split_ny = convert_to_list_dict(path, file_list[4])



test_split = test_split_no + test_split_ny
gold_split = TRUE_test_split_no + TRUE_test_split_ny
# Out:
# Converting no_bokmaal-ud-test to list of dictionaries
#      1939 elements converted..
# Converting no_nynorsk-ud-test to list of dictionaries
#      1511 elements converted..
# Converting no_bokmaal-ud-test to list of dictionaries
#      1939 elements converted..
# Converting no_nynorsk-ud-test to list of dictionaries
#      1511 elements converted..

# %%
nlp = spacy.load("nb_core_news_lg")

# %%
test_split
# Out:
# [{'idx': '018107',
#   'text': 'honnørordene er "dristig formspråk", " nyskapning " og "livgivende kontrast".',
#   'tokens': ['honnørordene',
#    'er',
#    '"',
#    'dristig',
#    'formspråk',
#    '"',
#    ',',
#    '"',
#    'nyskapning',
#    '"',
#    'og',
#    '"',
#    'livgivende',
#    'kontrast',
#    '"',
#    '.'],
#   'lemmas': ['honnørord',
#    'være',
#    '$"',
#    'dristig',
#    'formspråk',
#    '$"',
#    '$,',
#    '$"',
#    'nyskapning',
#    '$"',
#    'og',
#    '$"',
#    'livgivende',
#    'kontrast',
#    '$"',
#    '$.'],
#   'pos_tags': ['NOUN',
#    'AUX',
#    'PUNCT',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PUNCT',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018108',
#   'text': 'jeg ser et landskap som er såret og i tilbaketrekning.',
#   'tokens': ['jeg',
#    'ser',
#    'et',
#    'landskap',
#    'som',
#    'er',
#    'såret',
#    'og',
#    'i',
#    'tilbaketrekning',
#    '.'],
#   'lemmas': ['jeg',
#    'se',
#    'en',
#    'landskap',
#    'som',
#    'være',
#    'såre',
#    'og',
#    'i',
#    'tilbaketrekning',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'CCONJ',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018109',
#   'text': 'hos mange etterlater det fremmedgjørelse.',
#   'tokens': ['hos', 'mange', 'etterlater', 'det', 'fremmedgjørelse', '.'],
#   'lemmas': ['hos', 'mange', 'etterlate', 'det', 'fremmedgjørelse', '$.'],
#   'pos_tags': ['ADP', 'ADJ', 'VERB', 'PRON', 'NOUN', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018110',
#   'text': 'før eller senere vil en hjemsøkt verden måtte innse behovet for å dempe arkitekturens preg av teknologiske inngrep i landskapet, delvis for å berge det som måtte være tilbake av likevekt, delvis for å beskytte mot fremmedgjørelse.',
#   'tokens': ['før',
#    'eller',
#    'senere',
#    'vil',
#    'en',
#    'hjemsøkt',
#    'verden',
#    'måtte',
#    'innse',
#    'behovet',
#    'for',
#    'å',
#    'dempe',
#    'arkitekturens',
#    'preg',
#    'av',
#    'teknologiske',
#    'inngrep',
#    'i',
#    'landskapet',
#    ',',
#    'delvis',
#    'for',
#    'å',
#    'berge',
#    'det',
#    'som',
#    'måtte',
#    'være',
#    'tilbake',
#    'av',
#    'likevekt',
#    ',',
#    'delvis',
#    'for',
#    'å',
#    'beskytte',
#    'mot',
#    'fremmedgjørelse',
#    '.'],
#   'lemmas': ['før',
#    'eller',
#    'sen',
#    'ville',
#    'en',
#    'hjemsøke',
#    'verden',
#    'måtte',
#    'innse',
#    'behov',
#    'for',
#    'å',
#    'dempe',
#    'arkitektur',
#    'preg',
#    'av',
#    'teknologisk',
#    'inngrep',
#    'i',
#    'landskap',
#    '$,',
#    'delvis',
#    'for',
#    'å',
#    'berge',
#    'det',
#    'som',
#    'måtte',
#    'være',
#    'tilbake',
#    'av',
#    'likevekt',
#    '$,',
#    'delvis',
#    'for',
#    'å',
#    'beskytte',
#    'mot',
#    'fremmedgjørelse',
#    '$.'],
#   'pos_tags': ['ADP',
#    'CCONJ',
#    'ADJ',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'SCONJ',
#    'PART',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'SCONJ',
#    'PART',
#    'VERB',
#    'PRON',
#    'PRON',
#    'AUX',
#    'AUX',
#    'ADP',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'ADP',
#    'PART',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018111',
#   'text': 'ikke minst lider noen bevaringsverdige miljøer, fordi dagens dogmer innen profesjonen vil forby at den nødvendige fornyelse i slike strøk skjer gjennom tilpasning til det gamle.',
#   'tokens': ['ikke',
#    'minst',
#    'lider',
#    'noen',
#    'bevaringsverdige',
#    'miljøer',
#    ',',
#    'fordi',
#    'dagens',
#    'dogmer',
#    'innen',
#    'profesjonen',
#    'vil',
#    'forby',
#    'at',
#    'den',
#    'nødvendige',
#    'fornyelse',
#    'i',
#    'slike',
#    'strøk',
#    'skjer',
#    'gjennom',
#    'tilpasning',
#    'til',
#    'det',
#    'gamle',
#    '.'],
#   'lemmas': ['ikke',
#    'liten',
#    'lide',
#    'noen',
#    'bevaringsverdig',
#    'miljø',
#    '$,',
#    'fordi',
#    'dag',
#    'dogme',
#    'innen',
#    'profesjon',
#    'ville',
#    'forby',
#    'at',
#    'den',
#    'nødvendig',
#    'fornyelse',
#    'i',
#    'slik',
#    'strøk',
#    'skje',
#    'gjennom',
#    'tilpasning',
#    'til',
#    'det',
#    'gammel',
#    '$.'],
#   'pos_tags': ['PART',
#    'ADJ',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'SCONJ',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'SCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018112',
#   'text': 'det nye slagordet er "tilpasning gjennom kontrast".',
#   'tokens': ['det',
#    'nye',
#    'slagordet',
#    'er',
#    '"',
#    'tilpasning',
#    'gjennom',
#    'kontrast',
#    '"',
#    '.'],
#   'lemmas': ['det',
#    'ny',
#    'slagord',
#    'være',
#    '$"',
#    'tilpasning',
#    'gjennom',
#    'kontrast',
#    '$"',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'PUNCT',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018113',
#   'text': 'dette er som george orwells nytale, av samme logiske gehalt som "fred er krig", "stillhet er larm", "lys er mørke".',
#   'tokens': ['dette',
#    'er',
#    'som',
#    'george',
#    'orwells',
#    'nytale',
#    ',',
#    'av',
#    'samme',
#    'logiske',
#    'gehalt',
#    'som',
#    '"',
#    'fred',
#    'er',
#    'krig',
#    '"',
#    ',',
#    '"',
#    'stillhet',
#    'er',
#    'larm',
#    '"',
#    ',',
#    '"',
#    'lys',
#    'er',
#    'mørke',
#    '"',
#    '.'],
#   'lemmas': ['dette',
#    'være',
#    'som',
#    'George',
#    'Orwell',
#    'nytale',
#    '$,',
#    'av',
#    'samme',
#    'logisk',
#    'gehalt',
#    'som',
#    '$"',
#    'fred',
#    'være',
#    'krig',
#    '$"',
#    '$,',
#    '$"',
#    'stillhet',
#    'være',
#    'larm',
#    '$"',
#    '$,',
#    '$"',
#    'lys',
#    'være',
#    'mørke',
#    '$"',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'PUNCT',
#    'NOUN',
#    'AUX',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'NOUN',
#    'AUX',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'NOUN',
#    'AUX',
#    'NOUN',
#    'PUNCT',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018114',
#   'text': 'et mindretall blant dem som tegner våre hus, prøver å fornye et mer klassisk eller tradisjonsinspirert formspråk, ut fra den erfaring at slike løsninger faktisk har vist seg å virke, og stundom er mer takknemlig å forene med miljøverdier, i tillegg til trivsel og skjønnhet.',
#   'tokens': ['et',
#    'mindretall',
#    'blant',
#    'dem',
#    'som',
#    'tegner',
#    'våre',
#    'hus',
#    ',',
#    'prøver',
#    'å',
#    'fornye',
#    'et',
#    'mer',
#    'klassisk',
#    'eller',
#    'tradisjonsinspirert',
#    'formspråk',
#    ',',
#    'ut',
#    'fra',
#    'den',
#    'erfaring',
#    'at',
#    'slike',
#    'løsninger',
#    'faktisk',
#    'har',
#    'vist',
#    'seg',
#    'å',
#    'virke',
#    ',',
#    'og',
#    'stundom',
#    'er',
#    'mer',
#    'takknemlig',
#    'å',
#    'forene',
#    'med',
#    'miljøverdier',
#    ',',
#    'i',
#    'tillegg',
#    'til',
#    'trivsel',
#    'og',
#    'skjønnhet',
#    '.'],
#   'lemmas': ['en',
#    'mindretall',
#    'blant',
#    'de',
#    'som',
#    'tegne',
#    'vår',
#    'hus',
#    '$,',
#    'prøve',
#    'å',
#    'fornye',
#    'en',
#    'mye',
#    'klassisk',
#    'eller',
#    'tradisjonsinspirere',
#    'formspråk',
#    '$,',
#    'ut',
#    'fra',
#    'den',
#    'erfaring',
#    'at',
#    'slik',
#    'løsning',
#    'faktisk',
#    'ha',
#    'vise',
#    'seg',
#    'å',
#    'virke',
#    '$,',
#    'og',
#    'stundom',
#    'være',
#    'mye',
#    'takknemlig',
#    'å',
#    'forene',
#    'med',
#    'miljøverdi',
#    '$,',
#    'i',
#    'tillegg',
#    'til',
#    'trivsel',
#    'og',
#    'skjønnhet',
#    '$.'],
#   'pos_tags': ['DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'PRON',
#    'VERB',
#    'PRON',
#    'NOUN',
#    'PUNCT',
#    'VERB',
#    'PART',
#    'VERB',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'ADP',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'ADJ',
#    'AUX',
#    'VERB',
#    'PRON',
#    'PART',
#    'VERB',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'AUX',
#    'ADJ',
#    'ADJ',
#    'PART',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018115',
#   'text': 'blant de toneangivende i bransjen blir slike avvik forsøkt bannlyst, gjerne med en strøm av ukvemsord om at de driver med " kopiering " av nedarvet formspråk, enten det tradisjonelle norske eller det klassiske.',
#   'tokens': ['blant',
#    'de',
#    'toneangivende',
#    'i',
#    'bransjen',
#    'blir',
#    'slike',
#    'avvik',
#    'forsøkt',
#    'bannlyst',
#    ',',
#    'gjerne',
#    'med',
#    'en',
#    'strøm',
#    'av',
#    'ukvemsord',
#    'om',
#    'at',
#    'de',
#    'driver',
#    'med',
#    '"',
#    'kopiering',
#    '"',
#    'av',
#    'nedarvet',
#    'formspråk',
#    ',',
#    'enten',
#    'det',
#    'tradisjonelle',
#    'norske',
#    'eller',
#    'det',
#    'klassiske',
#    '.'],
#   'lemmas': ['blant',
#    'de',
#    'toneangivende',
#    'i',
#    'bransje',
#    'bli',
#    'slik',
#    'avvik',
#    'forsøke',
#    'bannlyse',
#    '$,',
#    'gjerne',
#    'med',
#    'en',
#    'strøm',
#    'av',
#    'ukvemsord',
#    'om',
#    'at',
#    'de',
#    'drive',
#    'med',
#    '$"',
#    'kopiering',
#    '$"',
#    'av',
#    'nedarvet',
#    'formspråk',
#    '$,',
#    'enten',
#    'det',
#    'tradisjonell',
#    'norsk',
#    'eller',
#    'det',
#    'klassisk',
#    '$.'],
#   'pos_tags': ['ADP',
#    'DET',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'DET',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'PUNCT',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'SCONJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'ADP',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'CCONJ',
#    'DET',
#    'ADJ',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018116',
#   'text': 'til gjengjeld får vi glede oss over at det blant våre tonekunstnere fortsatt er tillatt for utøverne å uttrykke seg gjennom folkemusikken eller gjennom den klassiske musikk.',
#   'tokens': ['til',
#    'gjengjeld',
#    'får',
#    'vi',
#    'glede',
#    'oss',
#    'over',
#    'at',
#    'det',
#    'blant',
#    'våre',
#    'tonekunstnere',
#    'fortsatt',
#    'er',
#    'tillatt',
#    'for',
#    'utøverne',
#    'å',
#    'uttrykke',
#    'seg',
#    'gjennom',
#    'folkemusikken',
#    'eller',
#    'gjennom',
#    'den',
#    'klassiske',
#    'musikk',
#    '.'],
#   'lemmas': ['til',
#    'gjengjeld',
#    'få',
#    'vi',
#    'glede',
#    'vi',
#    'over',
#    'at',
#    'det',
#    'blant',
#    'vår',
#    'tonekunstner',
#    'fortsatt',
#    'være',
#    'tillate',
#    'for',
#    'utøver',
#    'å',
#    'uttrykke',
#    'seg',
#    'gjennom',
#    'folkemusikk',
#    'eller',
#    'gjennom',
#    'den',
#    'klassisk',
#    'musikk',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NOUN',
#    'AUX',
#    'PRON',
#    'VERB',
#    'PRON',
#    'SCONJ',
#    'SCONJ',
#    'PRON',
#    'ADP',
#    'PRON',
#    'NOUN',
#    'ADV',
#    'AUX',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'NOUN',
#    'CCONJ',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018117',
#   'text': 'om byggekunstens smaksdommere var forbildet, ville det sett stygt ut for folkevisen og den klassiske symfoni.',
#   'tokens': ['om',
#    'byggekunstens',
#    'smaksdommere',
#    'var',
#    'forbildet',
#    ',',
#    'ville',
#    'det',
#    'sett',
#    'stygt',
#    'ut',
#    'for',
#    'folkevisen',
#    'og',
#    'den',
#    'klassiske',
#    'symfoni',
#    '.'],
#   'lemmas': ['om',
#    'byggekunst',
#    'smaksdommer',
#    'være',
#    'forbilde',
#    '$,',
#    'ville',
#    'det',
#    'se',
#    'stygg',
#    'ut',
#    'for',
#    'folkevise',
#    'og',
#    'den',
#    'klassisk',
#    'symfoni',
#    '$.'],
#   'pos_tags': ['SCONJ',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'ADP',
#    'ADP',
#    'NOUN',
#    'CCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018118',
#   'text': 'i diktet "om å vokse nedover" skriver rolf jacobsen:',
#   'tokens': ['i',
#    'diktet',
#    '"',
#    'om',
#    'å',
#    'vokse',
#    'nedover',
#    '"',
#    'skriver',
#    'rolf',
#    'jacobsen',
#    ':'],
#   'lemmas': ['i',
#    'dikt',
#    '$"',
#    'Om',
#    'å',
#    'vokse',
#    'nedover',
#    '$"',
#    'skrive',
#    'Rolf',
#    'Jacobsen',
#    '$:'],
#   'pos_tags': ['ADP',
#    'NOUN',
#    'PUNCT',
#    'PROPN',
#    'PART',
#    'VERB',
#    'ADP',
#    'PUNCT',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'B-PROD',
#    'I-PROD',
#    'I-PROD',
#    'I-PROD',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O']},
#  {'idx': '018119',
#   'text': 'jo større byene blir jo mindre blir menneskene.',
#   'tokens': ['jo',
#    'større',
#    'byene',
#    'blir',
#    'jo',
#    'mindre',
#    'blir',
#    'menneskene',
#    '.'],
#   'lemmas': ['jo',
#    'stor',
#    'by',
#    'bli',
#    'jo',
#    'liten',
#    'bli',
#    'menneske',
#    '$.'],
#   'pos_tags': ['ADV',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'ADJ',
#    'VERB',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018120',
#   'text': 'jo høyere husene stikker mot skyene jo lavere blir de som må bo der.',
#   'tokens': ['jo',
#    'høyere',
#    'husene',
#    'stikker',
#    'mot',
#    'skyene',
#    'jo',
#    'lavere',
#    'blir',
#    'de',
#    'som',
#    'må',
#    'bo',
#    'der',
#    '.'],
#   'lemmas': ['jo',
#    'høy',
#    'hus',
#    'stikke',
#    'mot',
#    'sky',
#    'jo',
#    'lav',
#    'bli',
#    'de',
#    'som',
#    'måtte',
#    'bo',
#    'der',
#    '$.'],
#   'pos_tags': ['ADV',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADV',
#    'ADJ',
#    'VERB',
#    'PRON',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADV',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018121',
#   'text': 'i new york er du bare 10 cm.',
#   'tokens': ['i', 'new', 'york', 'er', 'du', 'bare', '10', 'cm', '.'],
#   'lemmas': ['i', 'New', 'York', 'være', 'du', 'bare', '10', 'cm', '$.'],
#   'pos_tags': ['ADP',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PRON',
#    'ADV',
#    'NUM',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'B-GPE_LOC', 'I-GPE_LOC', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018122',
#   'text': 'i london og singapore kanskje en engelsk fot.',
#   'tokens': ['i',
#    'london',
#    'og',
#    'singapore',
#    'kanskje',
#    'en',
#    'engelsk',
#    'fot',
#    '.'],
#   'lemmas': ['i',
#    'London',
#    'og',
#    'Singapore',
#    'kanskje',
#    'en',
#    'engelsk',
#    'fot',
#    '$.'],
#   'pos_tags': ['ADP',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'ADV',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'B-GPE_LOC', 'O', 'B-GPE_LOC', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018123',
#   'text': 'og byen vokser og vokser og livet ditt blir mindre og mindre verd.',
#   'tokens': ['og',
#    'byen',
#    'vokser',
#    'og',
#    'vokser',
#    'og',
#    'livet',
#    'ditt',
#    'blir',
#    'mindre',
#    'og',
#    'mindre',
#    'verd',
#    '.'],
#   'lemmas': ['og',
#    'by',
#    'vokse',
#    'og',
#    'vokse',
#    'og',
#    'liv',
#    'din',
#    'bli',
#    'liten',
#    'og',
#    'liten',
#    'verd',
#    '$.'],
#   'pos_tags': ['CCONJ',
#    'NOUN',
#    'VERB',
#    'CCONJ',
#    'VERB',
#    'CCONJ',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'ADJ',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018124',
#   'text': 'snart er vi høye som gresstuster bare, og kan tas med en plenklipper tidlig en søndag formiddag.',
#   'tokens': ['snart',
#    'er',
#    'vi',
#    'høye',
#    'som',
#    'gresstuster',
#    'bare',
#    ',',
#    'og',
#    'kan',
#    'tas',
#    'med',
#    'en',
#    'plenklipper',
#    'tidlig',
#    'en',
#    'søndag',
#    'formiddag',
#    '.'],
#   'lemmas': ['snar',
#    'være',
#    'vi',
#    'høy',
#    'som',
#    'gresstust',
#    'bare',
#    '$,',
#    'og',
#    'kunne',
#    'ta',
#    'med',
#    'en',
#    'plenklipper',
#    'tidlig',
#    'en',
#    'søndag',
#    'formiddag',
#    '$.'],
#   'pos_tags': ['ADJ',
#    'AUX',
#    'PRON',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'ADV',
#    'PUNCT',
#    'CCONJ',
#    'AUX',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADJ',
#    'DET',
#    'NOUN',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018125',
#   'text': 'eller hva tror du?',
#   'tokens': ['eller', 'hva', 'tror', 'du', '?'],
#   'lemmas': ['eller', 'hva', 'tro', 'du', '$?'],
#   'pos_tags': ['CCONJ', 'PRON', 'VERB', 'PRON', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O']},
#  {'idx': '018126',
#   'text': 'hvordan skal det gå med eu?',
#   'tokens': ['hvordan', 'skal', 'det', 'gå', 'med', 'eu', '?'],
#   'lemmas': ['hvordan', 'skulle', 'det', 'gå', 'med', 'EU', '$?'],
#   'pos_tags': ['ADV', 'AUX', 'PRON', 'VERB', 'ADP', 'PROPN', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'B-GPE_ORG', 'O']},
#  {'idx': '018127',
#   'text': 'tyrkia.',
#   'tokens': ['tyrkia', '.'],
#   'lemmas': ['Tyrkia', '$.'],
#   'pos_tags': ['PROPN', 'PUNCT'],
#   'ner_tags': ['B-GPE_LOC', 'O']},
#  {'idx': '018128',
#   'text': 'det skrives mye om hvordan øst-asia stiger opp og usa faller ned.',
#   'tokens': ['det',
#    'skrives',
#    'mye',
#    'om',
#    'hvordan',
#    'øst-asia',
#    'stiger',
#    'opp',
#    'og',
#    'usa',
#    'faller',
#    'ned',
#    '.'],
#   'lemmas': ['det',
#    'skrive',
#    'mye',
#    'om',
#    'hvordan',
#    'Øst-Asia',
#    'stige',
#    'opp',
#    'og',
#    'USA',
#    'falle',
#    'ned',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADJ',
#    'SCONJ',
#    'ADV',
#    'PROPN',
#    'VERB',
#    'ADP',
#    'CCONJ',
#    'PROPN',
#    'VERB',
#    'ADP',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018129',
#   'text': 'men i den nye internasjonale orden er det europa og eu som har de største problemene.',
#   'tokens': ['men',
#    'i',
#    'den',
#    'nye',
#    'internasjonale',
#    'orden',
#    'er',
#    'det',
#    'europa',
#    'og',
#    'eu',
#    'som',
#    'har',
#    'de',
#    'største',
#    'problemene',
#    '.'],
#   'lemmas': ['men',
#    'i',
#    'den',
#    'ny',
#    'internasjonal',
#    'orden',
#    'være',
#    'det',
#    'Europa',
#    'og',
#    'EU',
#    'som',
#    'ha',
#    'de',
#    'stor',
#    'problem',
#    '$.'],
#   'pos_tags': ['CCONJ',
#    'ADP',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'PRON',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'PRON',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018130',
#   'text': 'i 1945 var storbritannia og kanskje også frankrike stormakter.',
#   'tokens': ['i',
#    '1945',
#    'var',
#    'storbritannia',
#    'og',
#    'kanskje',
#    'også',
#    'frankrike',
#    'stormakter',
#    '.'],
#   'lemmas': ['i',
#    '1945',
#    'være',
#    'Storbritannia',
#    'og',
#    'kanskje',
#    'også',
#    'Frankrike',
#    'stormakt',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NUM',
#    'AUX',
#    'PROPN',
#    'CCONJ',
#    'ADV',
#    'ADV',
#    'PROPN',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O']},
#  {'idx': '018131',
#   'text': 'det er de knapt i dag.',
#   'tokens': ['det', 'er', 'de', 'knapt', 'i', 'dag', '.'],
#   'lemmas': ['det', 'være', 'de', 'knapp', 'i', 'dag', '$.'],
#   'pos_tags': ['PRON', 'AUX', 'PRON', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018132',
#   'text': 'den økonomiske veksten har vært relativt lav i europa gjennom flere tiår.',
#   'tokens': ['den',
#    'økonomiske',
#    'veksten',
#    'har',
#    'vært',
#    'relativt',
#    'lav',
#    'i',
#    'europa',
#    'gjennom',
#    'flere',
#    'tiår',
#    '.'],
#   'lemmas': ['den',
#    'økonomisk',
#    'vekst',
#    'ha',
#    'være',
#    'relativ',
#    'lav',
#    'i',
#    'Europa',
#    'gjennom',
#    'mange',
#    'tiår',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'AUX',
#    'ADJ',
#    'ADJ',
#    'ADP',
#    'PROPN',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018133',
#   'text': 'mange har pekt på eu som løsning på europas problemer.',
#   'tokens': ['mange',
#    'har',
#    'pekt',
#    'på',
#    'eu',
#    'som',
#    'løsning',
#    'på',
#    'europas',
#    'problemer',
#    '.'],
#   'lemmas': ['mange',
#    'ha',
#    'peke',
#    'på',
#    'EU',
#    'som',
#    'løsning',
#    'på',
#    'Europa',
#    'problem',
#    '$.'],
#   'pos_tags': ['ADJ',
#    'AUX',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'SCONJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O']},
#  {'idx': '018134',
#   'text': 'eu har vært en suksess i den forstand at det har klart å kombinere geografisk utvidelse og innholdsmessig fordypelse.',
#   'tokens': ['eu',
#    'har',
#    'vært',
#    'en',
#    'suksess',
#    'i',
#    'den',
#    'forstand',
#    'at',
#    'det',
#    'har',
#    'klart',
#    'å',
#    'kombinere',
#    'geografisk',
#    'utvidelse',
#    'og',
#    'innholdsmessig',
#    'fordypelse',
#    '.'],
#   'lemmas': ['EU',
#    'ha',
#    'være',
#    'en',
#    'suksess',
#    'i',
#    'den',
#    'forstand',
#    'at',
#    'det',
#    'ha',
#    'klare',
#    'å',
#    'kombinere',
#    'geografisk',
#    'utvidelse',
#    'og',
#    'innholdsmessig',
#    'fordypelse',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'AUX',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'PART',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018135',
#   'text': 'geografisk har integrasjonen gått fra seks til nå å omfatte 27 medlemsland.',
#   'tokens': ['geografisk',
#    'har',
#    'integrasjonen',
#    'gått',
#    'fra',
#    'seks',
#    'til',
#    'nå',
#    'å',
#    'omfatte',
#    '27',
#    'medlemsland',
#    '.'],
#   'lemmas': ['geografisk',
#    'ha',
#    'integrasjon',
#    'gå',
#    'fra',
#    'seks',
#    'til',
#    'nå',
#    'å',
#    'omfatte',
#    '27',
#    'medlemsland',
#    '$.'],
#   'pos_tags': ['ADJ',
#    'AUX',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NUM',
#    'SCONJ',
#    'ADV',
#    'PART',
#    'VERB',
#    'NUM',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018136',
#   'text': 'innholdsmessig har en gått fra en kull- og stålunion til et stadig mer integrert felles marked med en i stor grad felles valuta og til iherdige forsøk på å etablere en felles utenriks- og sikkerhetspolitikk.',
#   'tokens': ['innholdsmessig',
#    'har',
#    'en',
#    'gått',
#    'fra',
#    'en',
#    'kull-',
#    'og',
#    'stålunion',
#    'til',
#    'et',
#    'stadig',
#    'mer',
#    'integrert',
#    'felles',
#    'marked',
#    'med',
#    'en',
#    'i',
#    'stor',
#    'grad',
#    'felles',
#    'valuta',
#    'og',
#    'til',
#    'iherdige',
#    'forsøk',
#    'på',
#    'å',
#    'etablere',
#    'en',
#    'felles',
#    'utenriks-',
#    'og',
#    'sikkerhetspolitikk',
#    '.'],
#   'lemmas': ['innholdsmessig',
#    'ha',
#    'en',
#    'gå',
#    'fra',
#    'en',
#    'Kull-',
#    'og',
#    'Stålunion',
#    'til',
#    'en',
#    'stadig',
#    'mye',
#    'integrere',
#    'felles',
#    'marked',
#    'med',
#    'en',
#    'i',
#    'stor',
#    'grad',
#    'felles',
#    'valuta',
#    'og',
#    'til',
#    'iherdig',
#    'forsøk',
#    'på',
#    'å',
#    'etablere',
#    'en',
#    'felles',
#    'utenriks-',
#    'og',
#    'sikkerhetspolitikk',
#    '$.'],
#   'pos_tags': ['ADJ',
#    'AUX',
#    'PRON',
#    'VERB',
#    'ADP',
#    'DET',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'PART',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018137',
#   'text': 'nå er det imidlertid mange som føler at begge disse to linjene nærmer seg et endepunkt og at de heller ikke lenger kan kombineres.',
#   'tokens': ['nå',
#    'er',
#    'det',
#    'imidlertid',
#    'mange',
#    'som',
#    'føler',
#    'at',
#    'begge',
#    'disse',
#    'to',
#    'linjene',
#    'nærmer',
#    'seg',
#    'et',
#    'endepunkt',
#    'og',
#    'at',
#    'de',
#    'heller',
#    'ikke',
#    'lenger',
#    'kan',
#    'kombineres',
#    '.'],
#   'lemmas': ['nå',
#    'være',
#    'det',
#    'imidlertid',
#    'mange',
#    'som',
#    'føle',
#    'at',
#    'begge',
#    'disse',
#    'to',
#    'linje',
#    'nærme',
#    'seg',
#    'en',
#    'endepunkt',
#    'og',
#    'at',
#    'de',
#    'heller',
#    'ikke',
#    'lenge',
#    'kunne',
#    'kombinere',
#    '$.'],
#   'pos_tags': ['ADV',
#    'VERB',
#    'PRON',
#    'ADV',
#    'ADJ',
#    'PRON',
#    'VERB',
#    'SCONJ',
#    'DET',
#    'DET',
#    'NUM',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'SCONJ',
#    'PRON',
#    'ADV',
#    'PART',
#    'ADJ',
#    'AUX',
#    'VERB',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018138',
#   'text': 'her er det imidlertid rom for nyanser.',
#   'tokens': ['her', 'er', 'det', 'imidlertid', 'rom', 'for', 'nyanser', '.'],
#   'lemmas': ['her', 'være', 'det', 'imidlertid', 'rom', 'for', 'nyanse', '$.'],
#   'pos_tags': ['ADV', 'VERB', 'PRON', 'ADV', 'NOUN', 'ADP', 'NOUN', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018139',
#   'text': 'eu vil ganske sikkert få flere nye medlemmer.',
#   'tokens': ['eu',
#    'vil',
#    'ganske',
#    'sikkert',
#    'få',
#    'flere',
#    'nye',
#    'medlemmer',
#    '.'],
#   'lemmas': ['EU',
#    'ville',
#    'ganske',
#    'sikker',
#    'få',
#    'mange',
#    'ny',
#    'medlem',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'VERB',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['B-GPE_ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018140',
#   'text': 'i tillegg til slovenia, som allerede er med, vil en hel serie stater fra det tidligere jugoslavia ganske sikkert bli medlemmer.',
#   'tokens': ['i',
#    'tillegg',
#    'til',
#    'slovenia',
#    ',',
#    'som',
#    'allerede',
#    'er',
#    'med',
#    ',',
#    'vil',
#    'en',
#    'hel',
#    'serie',
#    'stater',
#    'fra',
#    'det',
#    'tidligere',
#    'jugoslavia',
#    'ganske',
#    'sikkert',
#    'bli',
#    'medlemmer',
#    '.'],
#   'lemmas': ['i',
#    'tillegg',
#    'til',
#    'Slovenia',
#    '$,',
#    'som',
#    'allerede',
#    'være',
#    'med',
#    '$,',
#    'ville',
#    'en',
#    'hel',
#    'serie',
#    'stat',
#    'fra',
#    'det',
#    'tidlig',
#    'Jugoslavia',
#    'ganske',
#    'sikker',
#    'bli',
#    'medlem',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'PRON',
#    'ADV',
#    'AUX',
#    'ADP',
#    'PUNCT',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'PROPN',
#    'ADV',
#    'ADJ',
#    'VERB',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018141',
#   'text': 'kroatia og makedonia er kommet lengst, men bosnia-hercegovina, montenegro, og kanskje sogar serbia vil antagelig komme med.',
#   'tokens': ['kroatia',
#    'og',
#    'makedonia',
#    'er',
#    'kommet',
#    'lengst',
#    ',',
#    'men',
#    'bosnia-hercegovina',
#    ',',
#    'montenegro',
#    ',',
#    'og',
#    'kanskje',
#    'sogar',
#    'serbia',
#    'vil',
#    'antagelig',
#    'komme',
#    'med',
#    '.'],
#   'lemmas': ['Kroatia',
#    'og',
#    'Makedonia',
#    'være',
#    'komme',
#    'lang',
#    '$,',
#    'men',
#    'Bosnia-Hercegovina',
#    '$,',
#    'Montenegro',
#    '$,',
#    'og',
#    'kanskje',
#    'sogar',
#    'Serbia',
#    'ville',
#    'antagelig',
#    'komme',
#    'med',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'CCONJ',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'PROPN',
#    'PUNCT',
#    'PROPN',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'ADV',
#    'PROPN',
#    'AUX',
#    'ADJ',
#    'VERB',
#    'ADP',
#    'PUNCT'],
#   'ner_tags': ['B-GPE_ORG',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018142',
#   'text': 'det samme gjelder albania og også kosovo.',
#   'tokens': ['det',
#    'samme',
#    'gjelder',
#    'albania',
#    'og',
#    'også',
#    'kosovo',
#    '.'],
#   'lemmas': ['det',
#    'samme',
#    'gjelde',
#    'Albania',
#    'og',
#    'også',
#    'Kosovo',
#    '$.'],
#   'pos_tags': ['DET',
#    'DET',
#    'VERB',
#    'PROPN',
#    'CCONJ',
#    'ADV',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'B-GPE_ORG', 'O', 'O', 'B-GPE_ORG', 'O']},
#  {'idx': '018143',
#   'text': 'på litt lengre sikt er det gode muligheter for at ukraina kan bli medlem av eu.',
#   'tokens': ['på',
#    'litt',
#    'lengre',
#    'sikt',
#    'er',
#    'det',
#    'gode',
#    'muligheter',
#    'for',
#    'at',
#    'ukraina',
#    'kan',
#    'bli',
#    'medlem',
#    'av',
#    'eu',
#    '.'],
#   'lemmas': ['på',
#    'litt',
#    'lang',
#    'sikt',
#    'være',
#    'det',
#    'god',
#    'mulighet',
#    'for',
#    'at',
#    'Ukraina',
#    'kunne',
#    'bli',
#    'medlem',
#    'av',
#    'EU',
#    '$.'],
#   'pos_tags': ['ADP',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O']},
#  {'idx': '018144',
#   'text': 'noe mer usikker er moldova, hviterussland og georgia og sogar kanskje også andre stater i kaukasus.',
#   'tokens': ['noe',
#    'mer',
#    'usikker',
#    'er',
#    'moldova',
#    ',',
#    'hviterussland',
#    'og',
#    'georgia',
#    'og',
#    'sogar',
#    'kanskje',
#    'også',
#    'andre',
#    'stater',
#    'i',
#    'kaukasus',
#    '.'],
#   'lemmas': ['noen',
#    'mye',
#    'usikker',
#    'være',
#    'Moldova',
#    '$,',
#    'Hviterussland',
#    'og',
#    'Georgia',
#    'og',
#    'sogar',
#    'kanskje',
#    'også',
#    'annen',
#    'stat',
#    'i',
#    'Kaukasus',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'ADJ',
#    'AUX',
#    'PROPN',
#    'PUNCT',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'CCONJ',
#    'ADV',
#    'ADV',
#    'ADV',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O']},
#  {'idx': '018145',
#   'text': 'tyrkia er det store spørsmålet, men det er vanskelig å skjønne at eu kan si nei til tyrkia etter at man har forhandlet med landet helt fra 1960-tallet.',
#   'tokens': ['tyrkia',
#    'er',
#    'det',
#    'store',
#    'spørsmålet',
#    ',',
#    'men',
#    'det',
#    'er',
#    'vanskelig',
#    'å',
#    'skjønne',
#    'at',
#    'eu',
#    'kan',
#    'si',
#    'nei',
#    'til',
#    'tyrkia',
#    'etter',
#    'at',
#    'man',
#    'har',
#    'forhandlet',
#    'med',
#    'landet',
#    'helt',
#    'fra',
#    '1960-tallet',
#    '.'],
#   'lemmas': ['Tyrkia',
#    'være',
#    'det',
#    'stor',
#    'spørsmål',
#    '$,',
#    'men',
#    'det',
#    'være',
#    'vanskelig',
#    'å',
#    'skjønne',
#    'at',
#    'EU',
#    'kunne',
#    'si',
#    'nei',
#    'til',
#    'Tyrkia',
#    'etter',
#    'at',
#    'man',
#    'ha',
#    'forhandle',
#    'med',
#    'land',
#    'hel',
#    'fra',
#    '1960-tall',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'PART',
#    'VERB',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'SCONJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018146',
#   'text': 'det største problemet blir nok ikke frankrike, men heller østerrikes negative holdning og kanskje også tyrkias egne ønsker.',
#   'tokens': ['det',
#    'største',
#    'problemet',
#    'blir',
#    'nok',
#    'ikke',
#    'frankrike',
#    ',',
#    'men',
#    'heller',
#    'østerrikes',
#    'negative',
#    'holdning',
#    'og',
#    'kanskje',
#    'også',
#    'tyrkias',
#    'egne',
#    'ønsker',
#    '.'],
#   'lemmas': ['det',
#    'stor',
#    'problem',
#    'bli',
#    'nok',
#    'ikke',
#    'Frankrike',
#    '$,',
#    'men',
#    'heller',
#    'Østerrike',
#    'negativ',
#    'holdning',
#    'og',
#    'kanskje',
#    'også',
#    'Tyrkia',
#    'egen',
#    'ønske',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'PART',
#    'PROPN',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'PROPN',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'ADV',
#    'ADV',
#    'PROPN',
#    'DET',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018147',
#   'text': 'det er vanskelig å se for seg russland som medlem av eu.',
#   'tokens': ['det',
#    'er',
#    'vanskelig',
#    'å',
#    'se',
#    'for',
#    'seg',
#    'russland',
#    'som',
#    'medlem',
#    'av',
#    'eu',
#    '.'],
#   'lemmas': ['det',
#    'være',
#    'vanskelig',
#    'å',
#    'se',
#    'for',
#    'seg',
#    'Russland',
#    'som',
#    'medlem',
#    'av',
#    'EU',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADJ',
#    'PART',
#    'VERB',
#    'ADP',
#    'PRON',
#    'PROPN',
#    'SCONJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O']},
#  {'idx': '018148',
#   'text': 'island kan godt bli medlem; det vil kunne skje relativt fort.',
#   'tokens': ['island',
#    'kan',
#    'godt',
#    'bli',
#    'medlem',
#    ';',
#    'det',
#    'vil',
#    'kunne',
#    'skje',
#    'relativt',
#    'fort',
#    '.'],
#   'lemmas': ['Island',
#    'kunne',
#    'god',
#    'bli',
#    'medlem',
#    '$;',
#    'det',
#    'ville',
#    'kunne',
#    'skje',
#    'relativ',
#    'fort',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'AUX',
#    'ADJ',
#    'VERB',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'ADJ',
#    'PUNCT'],
#   'ner_tags': ['B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018149',
#   'text': 'det eneste som på kort sikt vil kunne bringe liv i en ny norsk eu-debatt, er antagelig at eu sier opp det som måtte være igjen av eøs-avtalen.',
#   'tokens': ['det',
#    'eneste',
#    'som',
#    'på',
#    'kort',
#    'sikt',
#    'vil',
#    'kunne',
#    'bringe',
#    'liv',
#    'i',
#    'en',
#    'ny',
#    'norsk',
#    'eu-debatt',
#    ',',
#    'er',
#    'antagelig',
#    'at',
#    'eu',
#    'sier',
#    'opp',
#    'det',
#    'som',
#    'måtte',
#    'være',
#    'igjen',
#    'av',
#    'eøs-avtalen',
#    '.'],
#   'lemmas': ['det',
#    'eneste',
#    'som',
#    'på',
#    'kort',
#    'sikt',
#    'ville',
#    'kunne',
#    'bringe',
#    'liv',
#    'i',
#    'en',
#    'ny',
#    'norsk',
#    'EU-debatt',
#    '$,',
#    'være',
#    'antagelig',
#    'at',
#    'EU',
#    'si',
#    'opp',
#    'det',
#    'som',
#    'måtte',
#    'være',
#    'igjen',
#    'av',
#    'EØS-avtalen',
#    '$.'],
#   'pos_tags': ['DET',
#    'NUM',
#    'PRON',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'ADJ',
#    'SCONJ',
#    'PROPN',
#    'VERB',
#    'ADP',
#    'PRON',
#    'PRON',
#    'AUX',
#    'AUX',
#    'ADV',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-DRV',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROD',
#    'O']},
#  {'idx': '018150',
#   'text': 'på den innholdsmessige siden har eu derimot større problemer.',
#   'tokens': ['på',
#    'den',
#    'innholdsmessige',
#    'siden',
#    'har',
#    'eu',
#    'derimot',
#    'større',
#    'problemer',
#    '.'],
#   'lemmas': ['på',
#    'den',
#    'innholdsmessig',
#    'side',
#    'ha',
#    'EU',
#    'derimot',
#    'stor',
#    'problem',
#    '$.'],
#   'pos_tags': ['ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'B-GPE_ORG', 'O', 'O', 'O', 'O']},
#  {'idx': '018151',
#   'text': 'enstemmig godkjennelse av traktater er svært krevende.',
#   'tokens': ['enstemmig',
#    'godkjennelse',
#    'av',
#    'traktater',
#    'er',
#    'svært',
#    'krevende',
#    '.'],
#   'lemmas': ['enstemmig',
#    'godkjennelse',
#    'av',
#    'traktat',
#    'være',
#    'svær',
#    'kreve',
#    '$.'],
#   'pos_tags': ['ADJ', 'NOUN', 'ADP', 'NOUN', 'AUX', 'ADJ', 'ADJ', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018152',
#   'text': 'utkastet til en konstitusjonell traktat ble stemt ned i frankrike og nederland i 2005.',
#   'tokens': ['utkastet',
#    'til',
#    'en',
#    'konstitusjonell',
#    'traktat',
#    'ble',
#    'stemt',
#    'ned',
#    'i',
#    'frankrike',
#    'og',
#    'nederland',
#    'i',
#    '2005',
#    '.'],
#   'lemmas': ['utkast',
#    'til',
#    'en',
#    'konstitusjonell',
#    'traktat',
#    'bli',
#    'stemme',
#    'ned',
#    'i',
#    'Frankrike',
#    'og',
#    'Nederland',
#    'i',
#    '2005',
#    '$.'],
#   'pos_tags': ['NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'ADP',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'ADP',
#    'NUM',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018153',
#   'text': 'lisboa-traktaten, som skulle redde de nye institusjonelle elementene, ble så forkastet i irland.',
#   'tokens': ['lisboa-traktaten',
#    ',',
#    'som',
#    'skulle',
#    'redde',
#    'de',
#    'nye',
#    'institusjonelle',
#    'elementene',
#    ',',
#    'ble',
#    'så',
#    'forkastet',
#    'i',
#    'irland',
#    '.'],
#   'lemmas': ['Lisboa-traktaten',
#    '$,',
#    'som',
#    'skulle',
#    'redde',
#    'de',
#    'ny',
#    'institusjonell',
#    'element',
#    '$,',
#    'bli',
#    'så',
#    'forkaste',
#    'i',
#    'Irland',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'VERB',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['B-PROD',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O']},
#  {'idx': '018154',
#   'text': 'dermed må eu inntil videre ledes på grunnlag av nice-avtalen fra 2000.',
#   'tokens': ['dermed',
#    'må',
#    'eu',
#    'inntil',
#    'videre',
#    'ledes',
#    'på',
#    'grunnlag',
#    'av',
#    'nice-avtalen',
#    'fra',
#    '2000',
#    '.'],
#   'lemmas': ['dermed',
#    'måtte',
#    'EU',
#    'inntil',
#    'vid',
#    'ledes',
#    'på',
#    'grunnlag',
#    'av',
#    'Nice-avtalen',
#    'fra',
#    '2000',
#    '$.'],
#   'pos_tags': ['ADV',
#    'AUX',
#    'PROPN',
#    'ADP',
#    'ADJ',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'ADP',
#    'NUM',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PROD',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018155',
#   'text': 'på område etter område ser vi at eu har store vanskeligheter med å få til større reformer.',
#   'tokens': ['på',
#    'område',
#    'etter',
#    'område',
#    'ser',
#    'vi',
#    'at',
#    'eu',
#    'har',
#    'store',
#    'vanskeligheter',
#    'med',
#    'å',
#    'få',
#    'til',
#    'større',
#    'reformer',
#    '.'],
#   'lemmas': ['på',
#    'område',
#    'etter',
#    'område',
#    'se',
#    'vi',
#    'at',
#    'EU',
#    'ha',
#    'stor',
#    'vanskelighet',
#    'med',
#    'å',
#    'få',
#    'til',
#    'stor',
#    'reform',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'SCONJ',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'PART',
#    'VERB',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018156',
#   'text': 'de økonomiske krisepakkene vedtas først og fremst på nasjonalstatsnivå; eus miljøsatsing er full av særordninger av alle mulige slag.',
#   'tokens': ['de',
#    'økonomiske',
#    'krisepakkene',
#    'vedtas',
#    'først',
#    'og',
#    'fremst',
#    'på',
#    'nasjonalstatsnivå',
#    ';',
#    'eus',
#    'miljøsatsing',
#    'er',
#    'full',
#    'av',
#    'særordninger',
#    'av',
#    'alle',
#    'mulige',
#    'slag',
#    '.'],
#   'lemmas': ['de',
#    'økonomisk',
#    'krisepakke',
#    'vedta',
#    'først',
#    'og',
#    'fremre',
#    'på',
#    'nasjonalstatsnivå',
#    '$;',
#    'EU',
#    'miljøsatsing',
#    'være',
#    'full',
#    'av',
#    'særordning',
#    'av',
#    'all',
#    'mulig',
#    'slag',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'CCONJ',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018157',
#   'text': 'ledelsen av eu skifter fortsatt hvert halvår.',
#   'tokens': ['ledelsen',
#    'av',
#    'eu',
#    'skifter',
#    'fortsatt',
#    'hvert',
#    'halvår',
#    '.'],
#   'lemmas': ['ledelse',
#    'av',
#    'EU',
#    'skifte',
#    'fortsatt',
#    'hver',
#    'halvår',
#    '$.'],
#   'pos_tags': ['NOUN', 'ADP', 'PROPN', 'VERB', 'ADV', 'DET', 'NOUN', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'B-GPE_ORG', 'O', 'O', 'O', 'O', 'O']},
#  {'idx': '018158',
#   'text': 'etter at sarkozy har hatt et hyperaktivt halvår, har skeptiske tsjekkia overtatt ledelsen.',
#   'tokens': ['etter',
#    'at',
#    'sarkozy',
#    'har',
#    'hatt',
#    'et',
#    'hyperaktivt',
#    'halvår',
#    ',',
#    'har',
#    'skeptiske',
#    'tsjekkia',
#    'overtatt',
#    'ledelsen',
#    '.'],
#   'lemmas': ['etter',
#    'at',
#    'Sarkozy',
#    'ha',
#    'ha',
#    'en',
#    'hyperaktiv',
#    'halvår',
#    '$,',
#    'ha',
#    'skeptisk',
#    'Tsjekkia',
#    'overta',
#    'ledelse',
#    '$.'],
#   'pos_tags': ['SCONJ',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'ADJ',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_ORG',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018159',
#   'text': 'dette er jo ikke noen måte å lede en seriøs organisasjon på.',
#   'tokens': ['dette',
#    'er',
#    'jo',
#    'ikke',
#    'noen',
#    'måte',
#    'å',
#    'lede',
#    'en',
#    'seriøs',
#    'organisasjon',
#    'på',
#    '.'],
#   'lemmas': ['dette',
#    'være',
#    'jo',
#    'ikke',
#    'noen',
#    'måte',
#    'å',
#    'lede',
#    'en',
#    'seriøs',
#    'organisasjon',
#    'på',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADV',
#    'PART',
#    'DET',
#    'NOUN',
#    'PART',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018160',
#   'text': 'på det utenrikspolitiske området er den felles utenriks-og sikkerhetspolitikk proklamert, men langt fra noen realitet.',
#   'tokens': ['på',
#    'det',
#    'utenrikspolitiske',
#    'området',
#    'er',
#    'den',
#    'felles',
#    'utenriks-',
#    'og',
#    'sikkerhetspolitikk',
#    'proklamert',
#    ',',
#    'men',
#    'langt',
#    'fra',
#    'noen',
#    'realitet',
#    '.'],
#   'lemmas': ['på',
#    'det',
#    'utenrikspolitisk',
#    'område',
#    'være',
#    'den',
#    'felles',
#    'utenriks-',
#    'og',
#    'sikkerhetspolitikk',
#    'proklamere',
#    '$,',
#    'men',
#    'lang',
#    'fra',
#    'noen',
#    'realitet',
#    '$.'],
#   'pos_tags': ['ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'VERB',
#    'PUNCT',
#    'CCONJ',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '018161',
#   'text': 'holdningene til usa og russland spriker.',
#   'tokens': ['holdningene', 'til', 'usa', 'og', 'russland', 'spriker', '.'],
#   'lemmas': ['holdning', 'til', 'USA', 'og', 'Russland', 'sprike', '$.'],
#   'pos_tags': ['NOUN', 'ADP', 'PROPN', 'CCONJ', 'PROPN', 'VERB', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'B-GPE_LOC', 'O', 'B-GPE_LOC', 'O', 'O']},
#  {'idx': '018162',
#   'text': 'forsvarsbudsjettene krymper.',
#   'tokens': ['forsvarsbudsjettene', 'krymper', '.'],
#   'lemmas': ['forsvarsbudsjett', 'krympe', '$.'],
#   'pos_tags': ['NOUN', 'VERB', 'PUNCT'],
#   'ner_tags': ['O', 'O', 'O']},
#  {'idx': '018163',
#   'text': 'eu vil fortsatt være «en konføderasjon av nasjonalstater».',
#   'tokens': ['eu',
#    'vil',
#    'fortsatt',
#    'være',
#    '«',
#    'en',
#    'konføderasjon',
#    'av',
#    'nasjonalstater',
#    '»',
#    '.'],
#   'lemmas': ['EU',
#    'ville',
#    'fortsatt',
#    'være',
#    '$"',
#    'en',
#    'konføderasjon',
#    'av',
#    'nasjonalstat',
#    '$"',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'AUX',
#    'ADV',
#    'AUX',
#    'PUNCT',
#    'DET',
#    'NOUN',
# ...
#    'O']},
#  {'idx': '019089',
#   'text': 'de første årene etter krigen var det bare et fåtall spedbarn hvert år som ble innlagt for adopsjon.',
#   'tokens': ['de',
#    'første',
#    'årene',
#    'etter',
#    'krigen',
#    'var',
#    'det',
#    'bare',
#    'et',
#    'fåtall',
#    'spedbarn',
#    'hvert',
#    'år',
#    'som',
#    'ble',
#    'innlagt',
#    'for',
#    'adopsjon',
#    '.'],
#   'lemmas': ['de',
#    'første',
#    'år',
#    'etter',
#    'krig',
#    'være',
#    'det',
#    'bare',
#    'en',
#    'fåtall',
#    'spedbarn',
#    'hver',
#    'år',
#    'som',
#    'bli',
#    'innlegge',
#    'for',
#    'adopsjon',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'PRON',
#    'ADV',
#    'DET',
#    'NOUN',
#    'NOUN',
#    'DET',
#    'NOUN',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019090',
#   'text': 'det fremgår av arkivet for barnehjemmet at haldorsen garanterte oppholdsutgiftene for flere av barna.',
#   'tokens': ['det',
#    'fremgår',
#    'av',
#    'arkivet',
#    'for',
#    'barnehjemmet',
#    'at',
#    'haldorsen',
#    'garanterte',
#    'oppholdsutgiftene',
#    'for',
#    'flere',
#    'av',
#    'barna',
#    '.'],
#   'lemmas': ['det',
#    'fremgå',
#    'av',
#    'arkiv',
#    'for',
#    'barnehjem',
#    'at',
#    'Haldorsen',
#    'garantere',
#    'oppholdsutgift',
#    'for',
#    'mange',
#    'av',
#    'barn',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'SCONJ',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019091',
#   'text': 'det gjorde garnæs også, trolig gjennom nasjonalhjelpen.',
#   'tokens': ['det',
#    'gjorde',
#    'garnæs',
#    'også',
#    ',',
#    'trolig',
#    'gjennom',
#    'nasjonalhjelpen',
#    '.'],
#   'lemmas': ['det',
#    'gjøre',
#    'Garnæs',
#    'også',
#    '$,',
#    'trolig',
#    'gjennom',
#    'Nasjonalhjelpen',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'PUNCT',
#    'ADJ',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'B-ORG', 'O']},
#  {'idx': '019092',
#   'text': 'fra 1951, det året garnæs ble ansatt som sosialkurator ved nasjonalhjelpen, tok virksomheten av.',
#   'tokens': ['fra',
#    '1951',
#    ',',
#    'det',
#    'året',
#    'garnæs',
#    'ble',
#    'ansatt',
#    'som',
#    'sosialkurator',
#    'ved',
#    'nasjonalhjelpen',
#    ',',
#    'tok',
#    'virksomheten',
#    'av',
#    '.'],
#   'lemmas': ['fra',
#    '1951',
#    '$,',
#    'det',
#    'år',
#    'Garnæs',
#    'bli',
#    'ansette',
#    'som',
#    'sosialkurator',
#    'ved',
#    'Nasjonalhjelpen',
#    '$,',
#    'ta',
#    'virksomhet',
#    'av',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NUM',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'SCONJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019093',
#   'text': 'i årene 1951 til -63 ble hvert år mellom 10 og 20 spedbarn fra chr. michelsens barnehjem bortadoptert, samtlige via nasjonalhjelpen.',
#   'tokens': ['i',
#    'årene',
#    '1951',
#    'til',
#    '-63',
#    'ble',
#    'hvert',
#    'år',
#    'mellom',
#    '10',
#    'og',
#    '20',
#    'spedbarn',
#    'fra',
#    'chr',
#    '.',
#    'michelsens',
#    'barnehjem',
#    'bortadoptert',
#    ',',
#    'samtlige',
#    'via',
#    'nasjonalhjelpen',
#    '.'],
#   'lemmas': ['i',
#    'år',
#    '1951',
#    'til',
#    '-63',
#    'bli',
#    'hver',
#    'år',
#    'mellom',
#    '10',
#    'og',
#    '20',
#    'spedbarn',
#    'fra',
#    'Chr',
#    '$.',
#    'Michelsens',
#    'barnehjem',
#    'bortadoptere',
#    '$,',
#    'samtlige',
#    'via',
#    'Nasjonalhjelpen',
#    '$.'],
#   'pos_tags': ['ADP',
#    'NOUN',
#    'NUM',
#    'ADP',
#    'NUM',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'CCONJ',
#    'NUM',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'PUNCT',
#    'PRON',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O']},
#  {'idx': '019094',
#   'text': 'de lå fra tre til seks uker på barnehjemmet før de ble levert adoptivforeldrene.',
#   'tokens': ['de',
#    'lå',
#    'fra',
#    'tre',
#    'til',
#    'seks',
#    'uker',
#    'på',
#    'barnehjemmet',
#    'før',
#    'de',
#    'ble',
#    'levert',
#    'adoptivforeldrene',
#    '.'],
#   'lemmas': ['de',
#    'ligge',
#    'fra',
#    'tre',
#    'til',
#    'seks',
#    'uke',
#    'på',
#    'barnehjem',
#    'før',
#    'de',
#    'bli',
#    'levere',
#    'adoptivforelder',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADP',
#    'NUM',
#    'ADP',
#    'NUM',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019095',
#   'text': 'de mangelfulle arkivene etter barnehjemmet viser at spedbarn kom fra betanien, lasarettet i sandviken og kvinneklinikken.',
#   'tokens': ['de',
#    'mangelfulle',
#    'arkivene',
#    'etter',
#    'barnehjemmet',
#    'viser',
#    'at',
#    'spedbarn',
#    'kom',
#    'fra',
#    'betanien',
#    ',',
#    'lasarettet',
#    'i',
#    'sandviken',
#    'og',
#    'kvinneklinikken',
#    '.'],
#   'lemmas': ['de',
#    'mangelfull',
#    'arkiv',
#    'etter',
#    'barnehjem',
#    'vise',
#    'at',
#    'spedbarn',
#    'komme',
#    'fra',
#    'Betanien',
#    '$,',
#    'Lasarettet',
#    'i',
#    'Sandviken',
#    'og',
#    'Kvinneklinikken',
#    '$.'],
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'VERB',
#    'SCONJ',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'PROPN',
#    'ADP',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'I-LOC',
#    'O',
#    'B-LOC',
#    'O']},
#  {'idx': '019096',
#   'text': 'haldorsen, som selv var fødselslege, hadde tatt imot flere av spedbarna, viser opplysninger i kartoteket.',
#   'tokens': ['haldorsen',
#    ',',
#    'som',
#    'selv',
#    'var',
#    'fødselslege',
#    ',',
#    'hadde',
#    'tatt',
#    'imot',
#    'flere',
#    'av',
#    'spedbarna',
#    ',',
#    'viser',
#    'opplysninger',
#    'i',
#    'kartoteket',
#    '.'],
#   'lemmas': ['Haldorsen',
#    '$,',
#    'som',
#    'selv',
#    'være',
#    'fødselslege',
#    '$,',
#    'ha',
#    'ta',
#    'imot',
#    'mange',
#    'av',
#    'spedbarn',
#    '$,',
#    'vise',
#    'opplysning',
#    'i',
#    'kartotek',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'PUNCT',
#    'PRON',
#    'ADV',
#    'AUX',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'VERB',
#    'ADP',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019097',
#   'text': 'i bergen byarkiv i arkivkassene etter inger haldorsen er det funnet flere drosjeregninger for reiser mellom norheimsund og os som nasjonalhjelpen betalte i forbindelse med adopsjonsformidling.',
#   'tokens': ['i',
#    'bergen',
#    'byarkiv',
#    'i',
#    'arkivkassene',
#    'etter',
#    'inger',
#    'haldorsen',
#    'er',
#    'det',
#    'funnet',
#    'flere',
#    'drosjeregninger',
#    'for',
#    'reiser',
#    'mellom',
#    'norheimsund',
#    'og',
#    'os',
#    'som',
#    'nasjonalhjelpen',
#    'betalte',
#    'i',
#    'forbindelse',
#    'med',
#    'adopsjonsformidling',
#    '.'],
#   'lemmas': ['i',
#    'Bergen',
#    'byarkiv',
#    'i',
#    'arkivkasse',
#    'etter',
#    'Inger',
#    'Haldorsen',
#    'være',
#    'det',
#    'finne',
#    'mange',
#    'drosjeregning',
#    'for',
#    'reise',
#    'mellom',
#    'Norheimsund',
#    'og',
#    'Os',
#    'som',
#    'Nasjonalhjelpen',
#    'betale',
#    'i',
#    'forbindelse',
#    'med',
#    'adopsjonsformidling',
#    '$.'],
#   'pos_tags': ['ADP',
#    'PROPN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'PRON',
#    'PROPN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019098',
#   'text': 'det tyder på at spedbarna også kom fra fødestuen i norheimsund.',
#   'tokens': ['det',
#    'tyder',
#    'på',
#    'at',
#    'spedbarna',
#    'også',
#    'kom',
#    'fra',
#    'fødestuen',
#    'i',
#    'norheimsund',
#    '.'],
#   'lemmas': ['det',
#    'tyde',
#    'på',
#    'at',
#    'spedbarn',
#    'også',
#    'komme',
#    'fra',
#    'fødestue',
#    'i',
#    'Norheimsund',
#    '$.'],
#   'pos_tags': ['PRON',
#    'VERB',
#    'SCONJ',
#    'SCONJ',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']},
#  {'idx': '019099',
#   'text': 'datteren til hjørdis djuvik har opplyst at også bergen helseråd formidlet spedbarn for adopsjon fra fødestuen i norheimsund.',
#   'tokens': ['datteren',
#    'til',
#    'hjørdis',
#    'djuvik',
#    'har',
#    'opplyst',
#    'at',
#    'også',
#    'bergen',
#    'helseråd',
#    'formidlet',
#    'spedbarn',
#    'for',
#    'adopsjon',
#    'fra',
#    'fødestuen',
#    'i',
#    'norheimsund',
#    '.'],
#   'lemmas': ['datter',
#    'til',
#    'Hjørdis',
#    'Djuvik',
#    'ha',
#    'opplyse',
#    'at',
#    'også',
#    'Bergen',
#    'Helseråd',
#    'formidle',
#    'spedbarn',
#    'for',
#    'adopsjon',
#    'fra',
#    'fødestue',
#    'i',
#    'Norheimsund',
#    '$.'],
#   'pos_tags': ['NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'SCONJ',
#    'ADV',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']},
#  {'idx': '019100',
#   'text': 'djuvik hadde avtale med en fast drosjeeier i os som kjørte henne til norheimsund.',
#   'tokens': ['djuvik',
#    'hadde',
#    'avtale',
#    'med',
#    'en',
#    'fast',
#    'drosjeeier',
#    'i',
#    'os',
#    'som',
#    'kjørte',
#    'henne',
#    'til',
#    'norheimsund',
#    '.'],
#   'lemmas': ['Djuvik',
#    'ha',
#    'avtale',
#    'med',
#    'en',
#    'fast',
#    'drosjeeier',
#    'i',
#    'Os',
#    'som',
#    'kjøre',
#    'hun',
#    'til',
#    'Norheimsund',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PRON',
#    'VERB',
#    'PRON',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O']},
#  {'idx': '019101',
#   'text': 'disse spedbarna ble plassert på barnehjem i bergen.',
#   'tokens': ['disse',
#    'spedbarna',
#    'ble',
#    'plassert',
#    'på',
#    'barnehjem',
#    'i',
#    'bergen',
#    '.'],
#   'lemmas': ['disse',
#    'spedbarn',
#    'bli',
#    'plassere',
#    'på',
#    'barnehjem',
#    'i',
#    'Bergen',
#    '$.'],
#   'pos_tags': ['DET',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE_LOC', 'O']},
#  {'idx': '019102',
#   'text': 'haldorsen drev en privat gynekologpraksis i richard nordraaks gate.',
#   'tokens': ['haldorsen',
#    'drev',
#    'en',
#    'privat',
#    'gynekologpraksis',
#    'i',
#    'richard',
#    'nordraaks',
#    'gate',
#    '.'],
#   'lemmas': ['Haldorsen',
#    'drive',
#    'en',
#    'privat',
#    'gynekologpraksis',
#    'i',
#    'Richard',
#    'Nordraaks',
#    'gate',
#    '$.'],
#   'pos_tags': ['PROPN',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'I-LOC',
#    'O']},
#  {'idx': '019103',
#   'text': 'hun var også faglig leder ved mødrehygienekontoret, et privat drevet, men offentlig finansiert rådgivningskontor for mødre og barn.',
#   'tokens': ['hun',
#    'var',
#    'også',
#    'faglig',
#    'leder',
#    'ved',
#    'mødrehygienekontoret',
#    ',',
#    'et',
#    'privat',
#    'drevet',
#    ',',
#    'men',
#    'offentlig',
#    'finansiert',
#    'rådgivningskontor',
#    'for',
#    'mødre',
#    'og',
#    'barn',
#    '.'],
#   'lemmas': ['hun',
#    'være',
#    'også',
#    'faglig',
#    'leder',
#    'ved',
#    'Mødrehygienekontoret',
#    '$,',
#    'en',
#    'privat',
#    'drive',
#    '$,',
#    'men',
#    'offentlig',
#    'finansiere',
#    'rådgivningskontor',
#    'for',
#    'mor',
#    'og',
#    'barn',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']},
#  {'idx': '019104',
#   'text': 'det er naturlig å anta at noen av kvinnene som ville adoptere kom via disse kanalene til nasjonalhjelpen.',
#   'tokens': ['det',
#    'er',
#    'naturlig',
#    'å',
#    'anta',
#    'at',
#    'noen',
#    'av',
#    'kvinnene',
#    'som',
#    'ville',
#    'adoptere',
#    'kom',
#    'via',
#    'disse',
#    'kanalene',
#    'til',
#    'nasjonalhjelpen',
#    '.'],
#   'lemmas': ['det',
#    'være',
#    'naturlig',
#    'å',
#    'anta',
#    'at',
#    'noen',
#    'av',
#    'kvinne',
#    'som',
#    'ville',
#    'adoptere',
#    'komme',
#    'via',
#    'disse',
#    'kanal',
#    'til',
#    'Nasjonalhjelpen',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADJ',
#    'PART',
#    'VERB',
#    'SCONJ',
#    'DET',
#    'ADP',
#    'NOUN',
#    'PRON',
#    'AUX',
#    'VERB',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O']},
#  {'idx': '019105',
#   'text': 'noen kan også ha tatt direkte kontakt med nasjonalhjelpens kontor i strandgaten 6.',
#   'tokens': ['noen',
#    'kan',
#    'også',
#    'ha',
#    'tatt',
#    'direkte',
#    'kontakt',
#    'med',
#    'nasjonalhjelpens',
#    'kontor',
#    'i',
#    'strandgaten',
#    '6',
#    '.'],
#   'lemmas': ['noen',
#    'kunne',
#    'også',
#    'ha',
#    'ta',
#    'direkte',
#    'kontakt',
#    'med',
#    'Nasjonalhjelpen',
#    'kontor',
#    'i',
#    'Strandgaten',
#    '6',
#    '$.'],
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADV',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'NUM',
#    'PUNCT'],
#   'ner_tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O']},
#  {'idx': '019106',
#   'text': 'her ble drevet sosialt arbeid for vanskeligstilte i ti-årene etter krigen.',
#   'tokens': ['her',
#    'ble',
#    'drevet',
#    'sosialt',
#    'arbeid',
#    'for',
#    'vanskeligstilte',
#    'i',
#    'ti-årene',
#    'etter',
#    'krigen',
#    '.'],
#   'lemmas': ['her',
#    'bli',
#    'drive',
#    'sosial',
#    'arbeid',
#    'for',
#    'vanskeligstilt',
#    'i',
#    'ti-år',
#    'etter',
#    'krig',
#    '$.'],
#   'pos_tags': ['ADV',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT'],
#   'ner_tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#  ...]

# %%
# implementing bindestrek fix

pred_sentences = []
for sen in test_split:
    doc = nlp(" ".join(sen["tokens"]))
    pred_sent = []
    for token in doc:
        ## Checking if "-" (bindestrek) in token. Such as in "Sør-Trøndelag"
        if token.ent_type_ != "": 
            if "-" in token.text:
                s = []
                for i, c in enumerate(token.text):
                    if i == 0:
                        s.append(c.capitalize())
                    elif c == "-":
                        s.append("-")
                    elif token.text[i-1] == "-":
                        s.append(c.capitalize())
                    else:
                        s.append(c)
                pred_sent.append("".join(s))
                continue
                
            pred_sent.append(token.text.capitalize())
        else:
            pred_sent.append(token.text)
    pred_sentences.append(" ".join(pred_sent))

# %%
pred_sentences_list = []
for sentence in pred_sentences:
    pred_sentences_list.append(sentence.split())

# %%
pred_annotations = []
for sentence in pred_sentences:
    annoation = []
    for token in sentence.split():
        if token[0].isupper(): # Checks if token has captial letter
            annoation.append(1)
        else:
            annoation.append(0) # Adds 0 if token has lower 
    pred_annotations.append((annoation))

# %%
# implementing bindestrek fix

gold_label_sentences = []
for sen in gold_split:
    doc = nlp(" ".join(sen["tokens"]))
    pred_sent = []
    for token in doc:
        ## Checking if "-" (bindestrek) in token. Such as in "Sør-Trøndelag"
        if token.ent_type_ != "": 
            if "-" in token.text:
                s = []
                for i, c in enumerate(token.text):
                    if i == 0:
                        s.append(c.capitalize())
                    elif c == "-":
                        s.append("-")
                    elif token.text[i-1] == "-":
                        s.append(c.capitalize())
                    else:
                        s.append(c)
                pred_sent.append("".join(s))
                continue
                
            pred_sent.append(token.text.capitalize())
        else:
            pred_sent.append(token.text)
    gold_label_sentences.append((pred_sent))

# %%
gold_labels = []
for sentence in gold_label_sentences:
    label = []
    for token in sentence:
        if token[0].isupper(): # Checks if token has captial letter
            label.append(1)
        else:
            label.append(0) # Adds 0 if token has lower 
    gold_labels.append((label))

# %%
# gold_labels = []
# for tags in test_split:
#     gold_labels.append(tags["ner_tags"])

# %%
# y_true = [item for sublist  in gold_labels for item in sublist]
# y_true = transform_to_binary(y_true)

# %%
y_pred = [item for sublist  in pred_annotations for item in sublist]
y_true = [item for sublist  in gold_labels for item in sublist]

# %%
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [56], line 1
# ----> 1 print(confusion_matrix(y_true, y_pred))
#       2 print(classification_report(y_true, y_pred))
#
# File c:\Users\Aarne\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:307, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     222 def confusion_matrix(
#     223     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     224 ):
#     225     """Compute confusion matrix to evaluate the accuracy of a classification.
#     226
#     227     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# File c:\Users\Aarne\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File c:\Users\Aarne\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:387, in check_consistent_length(*arrays)
#     385 uniques = np.unique(lengths)
#     386 if len(uniques) > 1:
# --> 387     raise ValueError(
#     388         "Found input variables with inconsistent numbers of samples: %r"
#     389         % [int(l) for l in lengths]
#     390     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [54746, 54749]

# %%
"""Making list of lists preds, same len as NorNE gold labels"""
""" test_dataset_ner_labels should be test_dataset.ner_labels """

def split_list_preds(preds, test_dataset_ner_labels):
    split_list_preds = []
    start = 0

    for sublist in test_dataset_ner_labels:
        end = start + len(sublist)
        split_list_preds.append(preds[start:end])
        start = end
    return split_list_preds

# %%
""" 
Because of how spacy tokenizes words, there is a slight discrepancy in the token count between gold and pred sets.
To counteract this, the 3 given sentences are dropped from both sets.
"""




for i, (t, p) in enumerate(zip(gold_labels, pred_annotations)):
    if len(t)!=len(p):
        print(f"{i}: {p} pred_sentences_list: {pred_sentences_list[i]}")
        print(f"true: {t} gold_label_sentences: {gold_label_sentences[i]}")
        print()


preds_copy = pred_annotations
gold_copy = gold_labels

index_remove_numbers = [1063, 1270, 1813]
for i, n in enumerate(index_remove_numbers):
    preds_copy.pop(n-i)
    gold_copy.pop(n-i)

# %%
for i, (t, p) in enumerate(zip(gold_copy, preds_copy)):
    if len(t)!=len(p):
        print(f"{i}: {p} pred_sentences_list: {pred_sentences_list[i]}")
        print(f"true: {t} gold_label_sentences: {gold_label_sentences[i]}")
        print()

# %%
y_pred = [item for sublist  in gold_copy for item in sublist]
y_true = [item for sublist  in preds_copy for item in sublist]

# %%
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# [[48032  4776]
#  [   35  1876]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     52808
#            1       0.28      0.98      0.44      1911
#
#     accuracy                           0.91     54719
#    macro avg       0.64      0.95      0.70     54719
# weighted avg       0.97      0.91      0.93     54719
